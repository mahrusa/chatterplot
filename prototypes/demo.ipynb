# %%
# %pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\14698\anaconda3\lib\site-packages (0.1.13)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.29 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (0.0.29)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.33 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (0.1.33)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (0.1.31)
# Requirement already satisfied: numpy<2,>=1 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (1.24.3)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (1.10.8)
# Requirement already satisfied: requests<3,>=2 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\14698\anaconda3\lib\site-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\14698\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\14698\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\14698\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.1)
# Requirement already satisfied: anyio<5,>=3 in c:\users\14698\anaconda3\lib\site-packages (from langchain-core<0.2.0,>=0.1.33->langchain) (3.5.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\14698\anaconda3\lib\site-packages (from langchain-core<0.2.0,>=0.1.33->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\14698\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.9.15)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\14698\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (4.9.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\14698\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\14698\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\14698\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\14698\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\14698\anaconda3\lib\site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.33->langchain) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\14698\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install llama_index
# Out:
# Collecting llama_index
#   Obtaining dependency information for llama_index from https://files.pythonhosted.org/packages/12/bb/7683ad928f14b2fc8919a6d9cd2f417cb5a6de872c33ecd148aef708f535/llama_index-0.10.22-py3-none-any.whl.metadata
#   Downloading llama_index-0.10.22-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-agent-openai<0.2.0,>=0.1.4 (from llama_index)
#   Obtaining dependency information for llama-index-agent-openai<0.2.0,>=0.1.4 from https://files.pythonhosted.org/packages/ac/05/53207df89fb47903f65695faa0895805c9fbf1c6ee5f2e8b433d4fdc75a9/llama_index_agent_openai-0.1.7-py3-none-any.whl.metadata
#   Downloading llama_index_agent_openai-0.1.7-py3-none-any.whl.metadata (644 bytes)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama_index)
#   Obtaining dependency information for llama-index-cli<0.2.0,>=0.1.2 from https://files.pythonhosted.org/packages/cf/77/1003907d0b46e2d793ed1db8933371f9e9991a938684eb01c26b86518321/llama_index_cli-0.1.11-py3-none-any.whl.metadata
#   Downloading llama_index_cli-0.1.11-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.11.0,>=0.10.22 (from llama_index)
#   Obtaining dependency information for llama-index-core<0.11.0,>=0.10.22 from https://files.pythonhosted.org/packages/9a/df/410d05ecae00f81b1c72576ab548e4e933e27f899a5186dec7151d9b3dfc/llama_index_core-0.10.23.post1-py3-none-any.whl.metadata
#   Downloading llama_index_core-0.10.23.post1-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama_index)
#   Obtaining dependency information for llama-index-embeddings-openai<0.2.0,>=0.1.5 from https://files.pythonhosted.org/packages/e4/d6/4623eb16f0e4ba2a716747f824451548ac5618f4093e1d0a9e0c66771e64/llama_index_embeddings_openai-0.1.7-py3-none-any.whl.metadata
#   Downloading llama_index_embeddings_openai-0.1.7-py3-none-any.whl.metadata (603 bytes)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama_index)
#   Obtaining dependency information for llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 from https://files.pythonhosted.org/packages/d5/4b/57282bc69de0ac29dfa170f491320836b58a3798c30b218dc3629326d13a/llama_index_indices_managed_llama_cloud-0.1.5-py3-none-any.whl.metadata
#   Downloading llama_index_indices_managed_llama_cloud-0.1.5-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama_index)
#   Obtaining dependency information for llama-index-legacy<0.10.0,>=0.9.48 from https://files.pythonhosted.org/packages/02/0a/0da9d27b0c3b074c1be1151ff4a4558f077c93df463310adfb47d193dde2/llama_index_legacy-0.9.48-py3-none-any.whl.metadata
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.2.0,>=0.1.5 (from llama_index)
#   Obtaining dependency information for llama-index-llms-openai<0.2.0,>=0.1.5 from https://files.pythonhosted.org/packages/27/3c/506ac78a9efe4909a17e67578e726b29d54d4b5fc4611f257de8ff599cf8/llama_index_llms_openai-0.1.12-py3-none-any.whl.metadata
#   Downloading llama_index_llms_openai-0.1.12-py3-none-any.whl.metadata (565 bytes)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama_index)
#   Obtaining dependency information for llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 from https://files.pythonhosted.org/packages/25/95/5ae22be545a28b12439a790f0672e41f4bfb50b8c2d1719038c05f5fe7a2/llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl.metadata
#   Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama_index)
#   Obtaining dependency information for llama-index-program-openai<0.2.0,>=0.1.3 from https://files.pythonhosted.org/packages/d1/39/4abdd53b4a26eaa9ccddbda30a7e8c5bd2470daf2fabe9e0e04336e0abde/llama_index_program_openai-0.1.4-py3-none-any.whl.metadata
#   Downloading llama_index_program_openai-0.1.4-py3-none-any.whl.metadata (766 bytes)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama_index)
#   Obtaining dependency information for llama-index-question-gen-openai<0.2.0,>=0.1.2 from https://files.pythonhosted.org/packages/2d/22/39f3ac5702b0e8ffd4d5a383c7cb2da0eb60f63b95f739345e79b66bf977/llama_index_question_gen_openai-0.1.3-py3-none-any.whl.metadata
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama_index)
#   Obtaining dependency information for llama-index-readers-file<0.2.0,>=0.1.4 from https://files.pythonhosted.org/packages/51/8f/4b8af6c7c7d4c093681d087acdb24c06356ef0e4a5a6200ea06d5075c818/llama_index_readers_file-0.1.12-py3-none-any.whl.metadata
#   Downloading llama_index_readers_file-0.1.12-py3-none-any.whl.metadata (970 bytes)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama_index)
#   Obtaining dependency information for llama-index-readers-llama-parse<0.2.0,>=0.1.2 from https://files.pythonhosted.org/packages/40/05/4578db57ee5ae53e2bfa111671be27fa80dc936858ce753db917f61a4bd6/llama_index_readers_llama_parse-0.1.3-py3-none-any.whl.metadata
#   Downloading llama_index_readers_llama_parse-0.1.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting PyYAML>=6.0.1 (from llama-index-core<0.11.0,>=0.10.22->llama_index)
#   Obtaining dependency information for PyYAML>=6.0.1 from https://files.pythonhosted.org/packages/b3/34/65bb4b2d7908044963ebf614fe0fdb080773fc7030d7e39c8d3eddcd4257/PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (2.0.28)
# Collecting aiohttp<4.0.0,>=3.8.6 (from llama-index-core<0.11.0,>=0.10.22->llama_index)
#   Obtaining dependency information for aiohttp<4.0.0,>=3.8.6 from https://files.pythonhosted.org/packages/a3/59/cd5e456835df696e6307c8b045acfada1557ac822d527c27bb33c1308091/aiohttp-3.9.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading aiohttp-3.9.3-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: dataclasses-json in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (0.6.4)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.11.0,>=0.10.22->llama_index)
#   Obtaining dependency information for deprecated>=1.2.9.3 from https://files.pythonhosted.org/packages/20/8d/778b7d51b981a96554f29136cd59ca7880bf58094338085bcf2a979a0e6a/Deprecated-1.2.14-py2.py3-none-any.whl.metadata
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.11.0,>=0.10.22->llama_index)
#   Obtaining dependency information for dirtyjson<2.0.0,>=1.0.8 from https://files.pythonhosted.org/packages/68/69/1bcf70f81de1b4a9f21b3a62ec0c83bdff991c88d6cc2267d02408457e88/dirtyjson-1.0.8-py3-none-any.whl.metadata
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (2024.3.1)
# Requirement already satisfied: httpx in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (0.27.0)
# Collecting llamaindex-py-client<0.2.0,>=0.1.13 (from llama-index-core<0.11.0,>=0.10.22->llama_index)
#   Obtaining dependency information for llamaindex-py-client<0.2.0,>=0.1.13 from https://files.pythonhosted.org/packages/94/ad/f0f8026cf1545b8b37ba5ad61dc62877745cf64b40be60be2310d779a8d1/llamaindex_py_client-0.1.13-py3-none-any.whl.metadata
#   Downloading llamaindex_py_client-0.1.13-py3-none-any.whl.metadata (762 bytes)
# Collecting nest-asyncio<2.0.0,>=1.5.8 (from llama-index-core<0.11.0,>=0.10.22->llama_index)
#   Obtaining dependency information for nest-asyncio<2.0.0,>=1.5.8 from https://files.pythonhosted.org/packages/a0/c4/c2971a3ba4c6103a3d10c4b0f24f461ddc027f0f09763220cf35ca1401b3/nest_asyncio-1.6.0-py3-none-any.whl.metadata
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: networkx>=3.0 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (3.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (3.8.1)
# Requirement already satisfied: numpy in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (1.24.3)
# Requirement already satisfied: openai>=1.1.0 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (1.14.2)
# Requirement already satisfied: pandas in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (8.2.2)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (0.6.0)
# Collecting tqdm<5.0.0,>=4.66.1 (from llama-index-core<0.11.0,>=0.10.22->llama_index)
#   Obtaining dependency information for tqdm<5.0.0,>=4.66.1 from https://files.pythonhosted.org/packages/2a/14/e75e52d521442e2fcc9f1df3c5e456aead034203d4797867980de558ab34/tqdm-4.66.2-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\14698\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.22->llama_index) (0.9.0)
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Obtaining dependency information for beautifulsoup4<5.0.0,>=4.12.3 from https://files.pythonhosted.org/packages/b1/fe/e8c672695b37eecc5cbf43e1d0638d88d66ba3a44c4d321c796f4e59167f/beautifulsoup4-4.12.3-py3-none-any.whl.metadata
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bs4<0.0.3,>=0.0.2 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Obtaining dependency information for bs4<0.0.3,>=0.0.2 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting pymupdf<2.0.0,>=1.23.21 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Obtaining dependency information for pymupdf<2.0.0,>=1.23.21 from https://files.pythonhosted.org/packages/7e/94/967c04c7e4aa0448eff481afdd1254240cb2cfc802f40af7d1212f0d13df/PyMuPDF-1.24.0-cp311-none-win_amd64.whl.metadata
#   Downloading PyMuPDF-1.24.0-cp311-none-win_amd64.whl.metadata (3.4 kB)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Obtaining dependency information for pypdf<5.0.0,>=4.0.1 from https://files.pythonhosted.org/packages/b8/1e/071b6684ee2b299a74a0bcdbf9a5441a1002920c72b6990b445d45c2b956/pypdf-4.1.0-py3-none-any.whl.metadata
#   Downloading pypdf-4.1.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Obtaining dependency information for striprtf<0.0.27,>=0.0.26 from https://files.pythonhosted.org/packages/a3/cf/0fea4f4ba3fc2772ac2419278aa9f6964124d4302117d61bc055758e000c/striprtf-0.0.26-py3-none-any.whl.metadata
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse<0.4.0,>=0.3.3 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama_index)
#   Obtaining dependency information for llama-parse<0.4.0,>=0.3.3 from https://files.pythonhosted.org/packages/df/8b/f0e7f337b54eae6044a72b6004d210a5c3b7044d372d7ec069c852025753/llama_parse-0.3.9-py3-none-any.whl.metadata
#   Downloading llama_parse-0.3.9-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.22->llama_index) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.22->llama_index) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\14698\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.8.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\14698\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (2.4)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\14698\anaconda3\lib\site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.14.1)
# Requirement already satisfied: pydantic>=1.10 in c:\users\14698\anaconda3\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.10.8)
# Requirement already satisfied: anyio in c:\users\14698\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.22->llama_index) (3.5.0)
# Requirement already satisfied: certifi in c:\users\14698\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.22->llama_index) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\14698\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.0.4)
# Requirement already satisfied: idna in c:\users\14698\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.22->llama_index) (3.4)
# Requirement already satisfied: sniffio in c:\users\14698\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\14698\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.22->llama_index) (0.14.0)
# Requirement already satisfied: click in c:\users\14698\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.22->llama_index) (8.0.4)
# Requirement already satisfied: joblib in c:\users\14698\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\14698\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.22->llama_index) (2022.7.9)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\14698\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.9.0)
# Collecting PyMuPDFb==1.24.0 (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Obtaining dependency information for PyMuPDFb==1.24.0 from https://files.pythonhosted.org/packages/db/de/b71bf2d7119ddf92583f5104bedb92ee106727b6548829dbd4baa5258310/PyMuPDFb-1.24.0-py3-none-win_amd64.whl.metadata
#   Downloading PyMuPDFb-1.24.0-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\14698\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.22->llama_index) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\14698\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.26.16)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\14698\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.22->llama_index) (2.0.1)
# Requirement already satisfied: colorama in c:\users\14698\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.22->llama_index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\14698\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\14698\anaconda3\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.22->llama_index) (3.21.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\14698\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.22->llama_index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\14698\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.22->llama_index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\14698\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.22->llama_index) (2023.3)
# Requirement already satisfied: packaging>=17.0 in c:\users\14698\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.22->llama_index) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\14698\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.22->llama_index) (1.16.0)
# Downloading llama_index-0.10.22-py3-none-any.whl (6.9 kB)
# Downloading llama_index_agent_openai-0.1.7-py3-none-any.whl (12 kB)
# Downloading llama_index_cli-0.1.11-py3-none-any.whl (26 kB)
# Downloading llama_index_core-0.10.23.post1-py3-none-any.whl (15.4 MB)
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.4 MB 16.6 MB/s eta 0:00:01
#    --- ------------------------------------ 1.2/15.4 MB 14.6 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.9/15.4 MB 17.0 MB/s eta 0:00:01
#    ------ --------------------------------- 2.5/15.4 MB 16.2 MB/s eta 0:00:01
#    -------- ------------------------------- 3.4/15.4 MB 16.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.0/15.4 MB 16.1 MB/s eta 0:00:01
#    ------------ --------------------------- 4.7/15.4 MB 16.8 MB/s eta 0:00:01
#    -------------- ------------------------- 5.4/15.4 MB 15.7 MB/s eta 0:00:01
#    -------------- ------------------------- 5.6/15.4 MB 14.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.3/15.4 MB 14.5 MB/s eta 0:00:01
#    ------------------ --------------------- 7.0/15.4 MB 14.9 MB/s eta 0:00:01
#    -------------------- ------------------- 7.7/15.4 MB 14.9 MB/s eta 0:00:01
#    --------------------- ------------------ 8.2/15.4 MB 15.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.9/15.4 MB 15.3 MB/s eta 0:00:01
#    ------------------------ --------------- 9.5/15.4 MB 15.2 MB/s eta 0:00:01
#    -------------------------- ------------- 10.2/15.4 MB 15.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.8/15.4 MB 15.6 MB/s eta 0:00:01
#    ------------------------------ --------- 11.6/15.4 MB 15.6 MB/s eta 0:00:01
#    ------------------------------- -------- 12.2/15.4 MB 15.2 MB/s eta 0:00:01
#    --------------------------------- ------ 12.9/15.4 MB 15.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.4 MB 15.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.3/15.4 MB 14.9 MB/s eta 0:00:01
#    -------------------------------------- - 14.9/15.4 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.4 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.4/15.4 MB 13.6 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.1.7-py3-none-any.whl (6.0 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.1.5-py3-none-any.whl (6.7 kB)
# Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------ --------------------------- 0.6/2.0 MB 13.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.4/2.0 MB 15.3 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 15.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 14.0 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.1.12-py3-none-any.whl (10 kB)
# Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl (5.8 kB)
# Downloading llama_index_program_openai-0.1.4-py3-none-any.whl (4.1 kB)
# Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.1.12-py3-none-any.whl (36 kB)
# Downloading llama_index_readers_llama_parse-0.1.3-py3-none-any.whl (2.5 kB)
# Downloading aiohttp-3.9.3-cp311-cp311-win_amd64.whl (365 kB)
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    --------------------------------------- 365.3/365.3 kB 23.7 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    ---------------------------------------- 147.9/147.9 kB 8.6 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading llama_parse-0.3.9-py3-none-any.whl (6.8 kB)
# Downloading llamaindex_py_client-0.1.13-py3-none-any.whl (107 kB)
#    ---------------------------------------- 0.0/108.0 kB ? eta -:--:--
#    ---------------------------------------- 108.0/108.0 kB 6.1 MB/s eta 0:00:00
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading PyMuPDF-1.24.0-cp311-none-win_amd64.whl (3.6 MB)
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.6/3.6 MB 19.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.5/3.6 MB 19.2 MB/s eta 0:00:01
#    ------------------------ --------------- 2.2/3.6 MB 15.8 MB/s eta 0:00:01
#    ------------------------------- -------- 2.8/3.6 MB 16.3 MB/s eta 0:00:01
#    -------------------------------------- - 3.5/3.6 MB 15.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.6/3.6 MB 14.4 MB/s eta 0:00:00
# Downloading PyMuPDFb-1.24.0-py3-none-win_amd64.whl (24.9 MB)
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    - -------------------------------------- 0.8/24.9 MB 16.7 MB/s eta 0:00:02
#    -- ------------------------------------- 1.6/24.9 MB 16.6 MB/s eta 0:00:02
#    --- ------------------------------------ 2.3/24.9 MB 16.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 2.9/24.9 MB 15.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 3.7/24.9 MB 15.8 MB/s eta 0:00:02
#    ------- -------------------------------- 4.5/24.9 MB 15.9 MB/s eta 0:00:02
#    -------- ------------------------------- 5.2/24.9 MB 15.9 MB/s eta 0:00:02
#    --------- ------------------------------ 5.8/24.9 MB 15.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.6/24.9 MB 16.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.2/24.9 MB 15.9 MB/s eta 0:00:02
#    ------------ --------------------------- 8.0/24.9 MB 15.9 MB/s eta 0:00:02
#    ------------- -------------------------- 8.7/24.9 MB 15.9 MB/s eta 0:00:02
#    --------------- ------------------------ 9.4/24.9 MB 16.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 10.1/24.9 MB 16.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 10.8/24.9 MB 16.0 MB/s eta 0:00:01
#    ------------------ --------------------- 11.5/24.9 MB 16.4 MB/s eta 0:00:01
#    ------------------- -------------------- 12.3/24.9 MB 16.0 MB/s eta 0:00:01
#    -------------------- ------------------- 13.0/24.9 MB 16.4 MB/s eta 0:00:01
#    --------------------- ------------------ 13.6/24.9 MB 16.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 14.2/24.9 MB 16.4 MB/s eta 0:00:01
#    ------------------------ --------------- 15.0/24.9 MB 16.0 MB/s eta 0:00:01
#    ------------------------- -------------- 15.6/24.9 MB 16.4 MB/s eta 0:00:01
#    ------------------------- -------------- 16.2/24.9 MB 16.4 MB/s eta 0:00:01
#    --------------------------- ------------ 16.9/24.9 MB 16.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 17.7/24.9 MB 16.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.5/24.9 MB 16.0 MB/s eta 0:00:01
#    ------------------------------ --------- 19.2/24.9 MB 16.4 MB/s eta 0:00:01
#    -------------------------------- ------- 20.1/24.9 MB 16.0 MB/s eta 0:00:01
#    --------------------------------- ------ 20.8/24.9 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.6/24.9 MB 16.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.3/24.9 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------- -- 23.1/24.9 MB 16.4 MB/s eta 0:00:01
#    -------------------------------------- - 23.9/24.9 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------  24.6/24.9 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------  24.9/24.9 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------  24.9/24.9 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------  24.9/24.9 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------- 24.9/24.9 MB 13.1 MB/s eta 0:00:00
# Downloading pypdf-4.1.0-py3-none-any.whl (286 kB)
#    ---------------------------------------- 0.0/286.1 kB ? eta -:--:--
#    --------------------------------------- 286.1/286.1 kB 18.4 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp311-cp311-win_amd64.whl (144 kB)
#    ---------------------------------------- 0.0/144.7 kB ? eta -:--:--
#    ---------------------------------------- 144.7/144.7 kB 8.4 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB ? eta 0:00:00
# Installing collected packages: striprtf, dirtyjson, tqdm, PyYAML, pypdf, PyMuPDFb, nest-asyncio, deprecated, beautifulsoup4, pymupdf, bs4, aiohttp, llamaindex-py-client, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama_index
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.6
#     Uninstalling nest-asyncio-1.5.6:
#       Successfully uninstalled nest-asyncio-1.5.6
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.2
#     Uninstalling beautifulsoup4-4.12.2:
#       Successfully uninstalled beautifulsoup4-4.12.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.5
#     Uninstalling aiohttp-3.8.5:
#       Successfully uninstalled aiohttp-3.8.5
# Successfully installed PyMuPDFb-1.24.0 PyYAML-6.0.1 aiohttp-3.9.3 beautifulsoup4-4.12.3 bs4-0.0.2 deprecated-1.2.14 dirtyjson-1.0.8 llama-index-agent-openai-0.1.7 llama-index-cli-0.1.11 llama-index-core-0.10.23.post1 llama-index-embeddings-openai-0.1.7 llama-index-indices-managed-llama-cloud-0.1.5 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.12 llama-index-multi-modal-llms-openai-0.1.4 llama-index-program-openai-0.1.4 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.12 llama-index-readers-llama-parse-0.1.3 llama-parse-0.3.9 llama_index-0.10.22 llamaindex-py-client-0.1.13 nest-asyncio-1.6.0 pymupdf-1.24.0 pypdf-4.1.0 striprtf-0.0.26 tqdm-4.66.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# s3fs 2023.4.0 requires fsspec==2023.4.0, but you have fsspec 2024.3.1 which is incompatible.

# %%
from llama_index import Document, SimpleDirectoryReader, GPTListIndex, GPTSimpleVectorIndex, LLMPredictor, PromptHelper
from langchain import OpenAI
import sys
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from llama_index import Document, SimpleDirectoryReader, GPTListIndex, GPTSimpleVectorIndex, LLMPredictor, PromptHelper
#       2 from langchain import OpenAI
#       3 import sys
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\__init__.py:21
#      18 from llama_index.embeddings.openai import OpenAIEmbedding
#      20 # structured
# ---> 21 from llama_index.indices.common.struct_store.base import SQLDocumentContextBuilder
#      23 # for composability
#      24 from llama_index.indices.composability.graph import ComposableGraph
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\indices\__init__.py:4
#       1 """LlamaIndex data structures."""
#       3 # indices
# ----> 4 from llama_index.indices.document_summary.base import DocumentSummaryIndex
#       5 from llama_index.indices.keyword_table.base import (
#       6     GPTKeywordTableIndex,
#       7     KeywordTableIndex,
#       8 )
#       9 from llama_index.indices.keyword_table.rake_base import (
#      10     GPTRAKEKeywordTableIndex,
#      11     RAKEKeywordTableIndex,
#      12 )
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\indices\document_summary\__init__.py:4
#       1 """Document summary index."""
# ----> 4 from llama_index.indices.document_summary.base import (
#       5     DocumentSummaryIndex,
#       6     GPTDocumentSummaryIndex,
#       7 )
#       8 from llama_index.indices.document_summary.retrievers import (
#       9     DocumentSummaryIndexEmbeddingRetriever,
#      10     DocumentSummaryIndexLLMRetriever,
#      11     DocumentSummaryIndexRetriever,
#      12 )
#      14 __all__ = [
#      15     "DocumentSummaryIndex",
#      16     "DocumentSummaryIndexLLMRetriever",
#    (...)
#      20     "DocumentSummaryIndexRetriever",
#      21 ]
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\indices\document_summary\base.py:14
#      11 from typing import Any, Dict, Optional, Sequence, Union, cast
#      13 from llama_index.data_structs.document_summary import IndexDocumentSummary
# ---> 14 from llama_index.indices.base import BaseIndex
#      15 from llama_index.indices.base_retriever import BaseRetriever
#      16 from llama_index.indices.service_context import ServiceContext
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\indices\base.py:6
#       3 from abc import ABC, abstractmethod
#       4 from typing import Any, Dict, Generic, List, Optional, Sequence, Type, TypeVar, cast
# ----> 6 from llama_index.chat_engine.types import BaseChatEngine, ChatMode
#       7 from llama_index.data_structs.data_structs import IndexStruct
#       8 from llama_index.indices.base_retriever import BaseRetriever
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\chat_engine\__init__.py:1
# ----> 1 from llama_index.chat_engine.condense_question import CondenseQuestionChatEngine
#       2 from llama_index.chat_engine.context import ContextChatEngine
#       3 from llama_index.chat_engine.simple import SimpleChatEngine
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\chat_engine\condense_question.py:6
#       3 from typing import Any, List, Optional, Type
#       5 from llama_index.callbacks import CallbackManager, trace_method
# ----> 6 from llama_index.chat_engine.types import (
#       7     AgentChatResponse,
#       8     BaseChatEngine,
#       9     StreamingAgentChatResponse,
#      10 )
#      11 from llama_index.chat_engine.utils import response_gen_from_query_engine
#      12 from llama_index.indices.query.base import BaseQueryEngine
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\chat_engine\types.py:14
#      12 from llama_index.response.schema import Response, StreamingResponse
#      13 from llama_index.schema import NodeWithScore
# ---> 14 from llama_index.tools import ToolOutput
#      16 logger = logging.getLogger(__name__)
#      17 logger.setLevel(logging.WARNING)
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\tools\__init__.py:5
#       3 from llama_index.tools.function_tool import FunctionTool
#       4 from llama_index.tools.query_engine import QueryEngineTool
# ----> 5 from llama_index.tools.query_plan import QueryPlanTool
#       6 from llama_index.tools.retriever_tool import RetrieverTool
#       7 from llama_index.tools.types import (
#       8     AsyncBaseTool,
#       9     BaseTool,
#    (...)
#      12     adapt_to_async_tool,
#      13 )
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\tools\query_plan.py:6
#       3 from typing import Any, Dict, List, Optional
#       5 from llama_index.bridge.pydantic import BaseModel, Field
# ----> 6 from llama_index.response_synthesizers import BaseSynthesizer, get_response_synthesizer
#       7 from llama_index.schema import NodeWithScore, TextNode
#       8 from llama_index.tools.types import BaseTool, ToolMetadata, ToolOutput
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\response_synthesizers\__init__.py:3
#       1 """Init file."""
# ----> 3 from llama_index.response_synthesizers.accumulate import Accumulate
#       4 from llama_index.response_synthesizers.base import BaseSynthesizer
#       5 from llama_index.response_synthesizers.compact_and_refine import CompactAndRefine
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\response_synthesizers\accumulate.py:5
#       2 from typing import Any, List, Optional, Sequence
#       4 from llama_index.async_utils import run_async_tasks
# ----> 5 from llama_index.indices.service_context import ServiceContext
#       6 from llama_index.prompts import BasePromptTemplate
#       7 from llama_index.prompts.default_prompts import DEFAULT_TEXT_QA_PROMPT
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\indices\service_context.py:10
#       8 from llama_index.embeddings.base import BaseEmbedding
#       9 from llama_index.embeddings.utils import EmbedType, resolve_embed_model
# ---> 10 from llama_index.indices.prompt_helper import PromptHelper
#      11 from llama_index.llm_predictor import LLMPredictor
#      12 from llama_index.llm_predictor.base import BaseLLMPredictor, LLMMetadata
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\indices\prompt_helper.py:16
#      14 from llama_index.bridge.pydantic import Field, PrivateAttr
#      15 from llama_index.constants import DEFAULT_CONTEXT_WINDOW, DEFAULT_NUM_OUTPUTS
# ---> 16 from llama_index.llm_predictor.base import LLMMetadata
#      17 from llama_index.llms.openai_utils import is_chat_model
#      18 from llama_index.prompts import BasePromptTemplate
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\llm_predictor\__init__.py:3
#       1 """Init params."""
# ----> 3 from llama_index.llm_predictor.base import LLMPredictor
#       5 # NOTE: this results in a circular import
#       6 # from llama_index.llm_predictor.mock import MockLLMPredictor
#       7 from llama_index.llm_predictor.structured import StructuredLLMPredictor
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\llm_predictor\base.py:18
#      11 from llama_index.llm_predictor.utils import (
#      12     astream_chat_response_to_tokens,
#      13     astream_completion_response_to_tokens,
#      14     stream_chat_response_to_tokens,
#      15     stream_completion_response_to_tokens,
#      16 )
#      17 from llama_index.llms.base import LLM, ChatMessage, LLMMetadata, MessageRole
# ---> 18 from llama_index.llms.utils import LLMType, resolve_llm
#      19 from llama_index.prompts.base import BasePromptTemplate, PromptTemplate
#      20 from llama_index.schema import BaseComponent
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\llms\__init__.py:23
#      21 from llama_index.llms.konko import Konko
#      22 from llama_index.llms.langchain import LangChainLLM
# ---> 23 from llama_index.llms.litellm import LiteLLM
#      24 from llama_index.llms.llama_cpp import LlamaCPP
#      25 from llama_index.llms.localai import LocalAI
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\llms\litellm.py:28
#       5 from llama_index.llms.base import (
#       6     LLM,
#       7     ChatMessage,
#    (...)
#      16     llm_completion_callback,
#      17 )
#      18 from llama_index.llms.generic_utils import (
#      19     achat_to_completion_decorator,
#      20     acompletion_to_chat_decorator,
#    (...)
#      26     stream_completion_to_chat_decorator,
#      27 )
# ---> 28 from llama_index.llms.litellm_utils import (
#      29     acompletion_with_retry,
#      30     completion_with_retry,
#      31     from_openai_message_dict,
#      32     is_chat_model,
#      33     is_function_calling_model,
#      34     openai_modelname_to_contextsize,
#      35     to_openai_message_dicts,
#      36     validate_litellm_api_key,
#      37 )
#      40 class LiteLLM(LLM):
#      41     model: str = Field(
#      42         description="The LiteLLM model to use."
#      43     )  # For complete list of providers https://docs.litellm.ai/docs/providers
#
# File c:\Users\14698\anaconda3\Lib\site-packages\llama_index\llms\litellm_utils.py:4
#       1 import logging
#       2 from typing import Any, Callable, Dict, List, Optional, Sequence, Type
# ----> 4 from openai.openai_object import OpenAIObject
#       5 from tenacity import (
#       6     before_sleep_log,
#       7     retry,
#    (...)
#      10     wait_exponential,
#      11 )
#      13 from llama_index.bridge.pydantic import BaseModel
#
# ModuleNotFoundError: No module named 'openai.openai_object'

# %%
os.environ["OPENAI_API_KEY"] = "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"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 os.environ["OPENAI_API_KEY"] = "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"
#
# NameError: name 'os' is not defined

# %%
def createVectorIndex(path):
    # specify variables so the model isnt overwhelmed
    max_input = 4096
    tokens = 256
    chunk_size = 600
    max_chunk_overlap = 20

    prompt_helper = PromptHelper(max_input, tokens, max_input, max_chunk_overlap, chunk_size_limit=chunk_size)

    # define the LLM
    llmPredictor = LLMPredictor(llm=OpenAI(temperature=0, model_name="text-ada-001", max_tokens=tokens))

    # load data
    data = SimpleDirectoryReader(path).load_data()

    # create vector index
    vectorIndex = GPTSimpleVectorIndex(documents=data, llm_predictor=llmPredictor, prompt_helper=prompt_helper)
    vectorIndex.save_to_disk('vectorIndex.json')
    return vectorIndex

# %%
def answerMe(vectorIndex):
    vector_index = GPTSimpleVectorIndex.load_from_disk(vectorIndex)
    while True:
        prompt = input("How may I help you?")
        response = vector_index.query(prompt, response_mode="compact")
        print(f"Response: () \n")
